# %%
import pandas as pd

# %%
data0 = pd.read_csv("prices_round_2_day_-1.csv", sep = ";")
data1 = pd.read_csv("prices_round_2_day_0.csv", sep = ";")
data2 = pd.read_csv("prices_round_2_day_1.csv", sep = ";")
all_data = pd.concat([data0, data1, data2], axis=0)
# all_data = [data0, data1, data2]
all_data.head()
# Out:
#    timestamp  ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF  \
# 0          0  1200.00             1.5           10.5           -2.0
# 1        100  1201.75             1.5            9.5           -2.0
# 2        200  1201.75             1.5            9.5           -2.0
# 3        300  1201.75             1.5            9.5           -2.0
# 4        400  1201.75             1.5            9.5           -2.0
#
#     SUNLIGHT  HUMIDITY  DAY
# 0  2500.0000  79.00000   -1
# 1  2499.4197  79.00410   -1
# 2  2498.8457  79.00821   -1
# 3  2498.2780  79.01234   -1
# 4  2497.7166  79.01649   -1

# %%
data = pd.read_csv("91b8434a-dd82-4b31-b24c-78c5add73e93.csv", sep=";")
data = data[data["product"]=="ORCHIDS"]
data.tail()
# Out:
#       day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 2986    1      99500  ORCHIDS         1067             5       1066.0
# 2988    1      99600  ORCHIDS         1068             7       1067.0
# 2991    1      99700  ORCHIDS         1068             5       1067.0
# 2996    1      99800  ORCHIDS         1068             8       1067.0
# 2998    1      99900  ORCHIDS         1067             7       1066.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 2986           4.0       1060.0          43.0         1074             5
# 2988           2.0       1061.0          46.0         1075             7
# 2991           3.0       1061.0          48.0         1076             5
# 2996           3.0       1061.0          49.0         1075             8
# 2998           4.0       1059.0          49.0         1074             7
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
data[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data[-1]
#
# ...
